# %% [markdown]
# <a href="https://colab.research.google.com/github/palakv07/Text_to_video/blob/main/Stable_diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -qqU diffusers transformers bitsandbytes accelerate ftfy datasets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 63.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 92.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.5/527.5 kB 29.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 16.2 MB/s eta 0:00:00

# %%
# %%capture
# !sudo apt -qq install git-lfs
# !git config --global credential.helper store

# %%
import ipywidgets as widgets

theme = "food"
drop_down = widgets.Dropdown(
    options=["animal", "science", "food", "landscape", "wildcard"],
    description="Pick a theme",
    disabled=False,
)


def dropdown_handler(change):
    global theme
    theme = change.new


drop_down.observe(dropdown_handler, names="value")
display(drop_down)
# Out:
# Dropdown(description='Pick a theme', options=('animal', 'science', 'food', 'landscape', 'wildcard'), value='an…

# %%
print(f"You've selected the {theme} theme!")
# Out:
# You've selected the food theme!

# %%
# !unzip Stable_diffusion.zip
# Out:
# Archive:  Stable_diffusion.zip
#    creating: Stable_diffusion/
#   inflating: Stable_diffusion/burger.avif
#   inflating: Stable_diffusion/download (1).webp
#   inflating: Stable_diffusion/download.webp
#   inflating: Stable_diffusion/OIP (1).webp
#   inflating: Stable_diffusion/OIP (10).webp
#   inflating: Stable_diffusion/OIP (2).webp
#   inflating: Stable_diffusion/OIP (3).webp
#   inflating: Stable_diffusion/OIP (4).webp
#   inflating: Stable_diffusion/OIP (5).webp
#   inflating: Stable_diffusion/OIP (6).webp
#   inflating: Stable_diffusion/OIP (7).webp
#   inflating: Stable_diffusion/OIP (8).webp
#   inflating: Stable_diffusion/OIP (9).webp
#   inflating: Stable_diffusion/OIP.jpg
#   inflating: Stable_diffusion/OIP.webp
